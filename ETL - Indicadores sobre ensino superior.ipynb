# %%
import pandas as pd
import numpy as np

# %% [markdown]
# # Leitura dos datasets
#
# ## Fonte dos datasets
#
# * PDA_Dados_Cursos_Graduacao_Brasil.csv -> https://dadosabertos.mec.gov.br/indicadores-sobre-ensino-superior
# * PDA_Lista_Instituicoes_Ensino_Superior_do_Brasil_EMEC.csv -> https://dadosabertos.mec.gov.br/indicadores-sobre-ensino-superior
# * ENADE 2022 -> https://download.inep.gov.br/educacao_superior/indicadores/resultados/2022/conceito_enade_2022.ods
# * Percentual de Docentes com Pós-Graduação stricto sensu (2022) -> https://download.inep.gov.br/dados_abertos/indicadores_educacionais/percentual_de_docentes_com_pos_graduacao_stricto_sensu/percentual_docente_2022.zip

# %%
cursos = pd.read_csv('PDA_Dados_Cursos_Graduacao_Brasil.csv')
instituicoes = pd.read_csv('PDA_Lista_Instituicoes_Ensino_Superior_do_Brasil_EMEC.csv')
enade = pd.read_csv('conceito_enade_2022.csv')
perc_docente = pd.read_csv('PERC_DOCENTES_BRASIL_2022.csv')

# %% [markdown]
# # Transformação dos dados

# %% [markdown]
# ## Percentual de docentes com pós-graduação stricto sensu

# %% [markdown]
# ### Seleção das colunas

# %%
perc_docente_n = perc_docente[["CO_IES", "PERCENTUAL_MESTRADO", "PERCENTUAL_DOUTORADO"]].copy()

# %% [markdown]
# ### Ajuste dos nomes das colunas

# %%
perc_docente_n = perc_docente_n.rename(columns={"CO_IES": "CODIGO_DA_IES"})

# %%
perc_docente_n
# Out:
#       CODIGO_DA_IES  PERCENTUAL_MESTRADO  PERCENTUAL_DOUTORADO
# 0                 1                 12.1                  80.7
# 1                 2                  7.7                  91.1
# 2                 3                 12.2                  84.1
# 3                 4                 23.3                  64.7
# 4                 5                 18.4                  76.5
# ...             ...                  ...                   ...
# 2586          25453                 50.0                   0.0
# 2587          25613                 10.6                   2.4
# 2588          25624                 50.0                  16.7
# 2589          25788                 25.0                  75.0
# 2590          27103                 32.4                   5.4
#
# [2591 rows x 3 columns]

# %% [markdown]
# ## Instituições de ensino superior

# %% [markdown]
# ### Remoção de instituições sem município

# %%
instituicoes = instituicoes.dropna(subset='CODIGO_MUNICIPIO_IBGE').reset_index(drop=True)
instituicoes["CODIGO_MUNICIPIO_IBGE"] = instituicoes["CODIGO_MUNICIPIO_IBGE"].astype(int)

# %% [markdown]
# ### Seleção das colunas

# %%
instituicoes_n = instituicoes[["CODIGO_DA_IES", "NOME_DA_IES", "SIGLA", 
                               "CATEGORIA_DA_IES", "ORGANIZACAO_ACADEMICA", 
                               "SITUACAO_IES", "CODIGO_MUNICIPIO_IBGE"]].copy()

# %% [markdown]
# ### Left join com dataset com dados sobre percentual de docente com pós stricto sensu

# %%
instituicoes_n = pd.merge(instituicoes_n, perc_docente_n, how='left', on='CODIGO_DA_IES')

# %%
instituicoes_n
# Out:
#       CODIGO_DA_IES                                        NOME_DA_IES  \
# 0             21995             Faculdade de Tecnologia Senac Curitiba
# 1              1768                         FACULDADE REGIONAL SERRANA
# 2              5701                    UNIVERSIDADE DO ESTADO DO AMAPÁ
# 3             23261       Faculdade São Judas de São Bernardo do Campo
# 4              4250  FACULDADE DE CIÊNCIAS GERENCIAIS ALVES FORTES ...
# ...             ...                                                ...
# 3865           5215                  CENTRO UNIVERSITÁRIO PADRE ALBINO
# 3866          19210                    Faculdades Integradas de Taguaí
# 3867           2514  Faculdade de Ciências Educacionais do Rio Gran...
# 3868          18454                       Faculdade Una de Sete Lagoas
# 3869          16010           FACULDADE DE ENSINO SUPERIOR DE LINHARES
#
#               SIGLA CATEGORIA_DA_IES ORGANIZACAO_ACADEMICA SITUACAO_IES  \
# 0               NaN          Privada             Faculdade        Ativa
# 1            FUNPAC          Privada             Faculdade      Extinta
# 2              UEAP          Pública          Universidade        Ativa
# 3               NaN          Privada             Faculdade        Ativa
# 4     FACE ALFOR JF          Privada             Faculdade      Extinta
# ...             ...              ...                   ...          ...
# 3865            NaN          Privada  Centro Universitário        Ativa
# 3866            FIT          Privada             Faculdade        Ativa
# 3867         FACERN          Privada             Faculdade        Ativa
# 3868         Unaset          Privada             Faculdade        Ativa
# 3869         FACELI          Pública             Faculdade        Ativa
#
#       CODIGO_MUNICIPIO_IBGE  PERCENTUAL_MESTRADO  PERCENTUAL_DOUTORADO
# 0                   4106902                 20.0                  10.0
# 1                   3205069                  NaN                   NaN
# 2                   1600303                 33.3                  46.8
# 3                   3548708                 60.0                  36.0
# 4                   3136702                  NaN                   NaN
# ...                     ...                  ...                   ...
# 3865                3511102                 34.2                  41.6
# 3866                3553005                 33.3                  11.9
# 3867                2408102                 28.6                   0.0
# 3868                3167202                 57.1                  14.3
# 3869                3203205                 80.0                  20.0
#
# [3870 rows x 9 columns]

# %% [markdown]
# ### Ajuste dos nomes das colunas

# %%
instituicoes_n = instituicoes_n.rename(columns={'CODIGO_DA_IES': 'COD_INSTITUICAO',
                                                'NOME_DA_IES': 'NOME_INSTITUICAO',
                                                'SITUACAO_IES': 'SITUACAO',
                                                'CATEGORIA_DA_IES': 'CATEGORIA',
                                                'PERCENTUAL_MESTRADO': 'PERCENTUAL_DOCENTES_MESTRADO',
                                                'PERCENTUAL_DOUTORADO': 'PERCENTUAL_DOCENTES_DOUTORADO',
                                                'CODIGO_MUNICIPIO_IBGE': 'COD_MUNICIPIO'})

# %%
instituicoes_n
# Out:
#       COD_INSTITUICAO                                   NOME_INSTITUICAO  \
# 0               21995             Faculdade de Tecnologia Senac Curitiba
# 1                1768                         FACULDADE REGIONAL SERRANA
# 2                5701                    UNIVERSIDADE DO ESTADO DO AMAPÁ
# 3               23261       Faculdade São Judas de São Bernardo do Campo
# 4                4250  FACULDADE DE CIÊNCIAS GERENCIAIS ALVES FORTES ...
# ...               ...                                                ...
# 3865             5215                  CENTRO UNIVERSITÁRIO PADRE ALBINO
# 3866            19210                    Faculdades Integradas de Taguaí
# 3867             2514  Faculdade de Ciências Educacionais do Rio Gran...
# 3868            18454                       Faculdade Una de Sete Lagoas
# 3869            16010           FACULDADE DE ENSINO SUPERIOR DE LINHARES
#
#               SIGLA CATEGORIA ORGANIZACAO_ACADEMICA SITUACAO  COD_MUNICIPIO  \
# 0               NaN   Privada             Faculdade    Ativa        4106902
# 1            FUNPAC   Privada             Faculdade  Extinta        3205069
# 2              UEAP   Pública          Universidade    Ativa        1600303
# 3               NaN   Privada             Faculdade    Ativa        3548708
# 4     FACE ALFOR JF   Privada             Faculdade  Extinta        3136702
# ...             ...       ...                   ...      ...            ...
# 3865            NaN   Privada  Centro Universitário    Ativa        3511102
# 3866            FIT   Privada             Faculdade    Ativa        3553005
# 3867         FACERN   Privada             Faculdade    Ativa        2408102
# 3868         Unaset   Privada             Faculdade    Ativa        3167202
# 3869         FACELI   Pública             Faculdade    Ativa        3203205
#
#       PERCENTUAL_DOCENTES_MESTRADO  PERCENTUAL_DOCENTES_DOUTORADO
# 0                             20.0                           10.0
# 1                              NaN                            NaN
# 2                             33.3                           46.8
# 3                             60.0                           36.0
# 4                              NaN                            NaN
# ...                            ...                            ...
# 3865                          34.2                           41.6
# 3866                          33.3                           11.9
# 3867                          28.6                            0.0
# 3868                          57.1                           14.3
# 3869                          80.0                           20.0
#
# [3870 rows x 9 columns]

# %% [markdown]
# ## Municípios

# %% [markdown]
# ### Extração da lista de municípios a partir do dataset de cursos

# %%
municipios_cursos = cursos[["CODIGO_MUNICIPIO", "MUNICIPIO", "UF", "REGIAO"]
                            ].drop_duplicates().reset_index(drop=True)

# %% [markdown]
# ### Extração da lista de municípios a partir do dataset de instituições

# %%
estados_regioes = {
    'AC': 'NORTE',
    'AL': 'NORDESTE',
    'AP': 'NORTE',
    'AM': 'NORTE',
    'BA': 'NORDESTE',
    'CE': 'NORDESTE',
    'DF': 'CENTRO-OESTE',
    'ES': 'SUDESTE',
    'GO': 'CENTRO-OESTE',
    'MA': 'NORDESTE',
    'MT': 'CENTRO-OESTE',
    'MS': 'CENTRO-OESTE',
    'MG': 'SUDESTE',
    'PA': 'NORTE',
    'PB': 'NORDESTE',
    'PR': 'SUL',
    'PE': 'NORDESTE',
    'PI': 'NORDESTE',
    'RJ': 'SUDESTE',
    'RN': 'NORDESTE',
    'RS': 'SUL',
    'RO': 'NORTE',
    'RR': 'NORTE',
    'SC': 'SUL',
    'SP': 'SUDESTE',
    'SE': 'NORDESTE',
    'TO': 'NORTE'
}

# %%
municipios_instituicoes = instituicoes[["CODIGO_MUNICIPIO_IBGE", "MUNICIPIO", "UF"]].drop_duplicates().reset_index(drop=True)
municipios_instituicoes["REGIAO"] = municipios_instituicoes.UF.apply(lambda x: estados_regioes[x])

# %% [markdown]
# ### Ajuste dos nomes das colunas

# %%
municipios_cursos = municipios_cursos.rename(columns={'CODIGO_MUNICIPIO': 'COD_MUNICIPIO',
                                                      'MUNICIPIO': 'NOME_MUNICIPIO'})

# %%
municipios_instituicoes = municipios_instituicoes.rename(columns={'CODIGO_MUNICIPIO_IBGE': 'COD_MUNICIPIO',
                                                                  'MUNICIPIO': 'NOME_MUNICIPIO'})

# %% [markdown]
# ### União dos datasets de municípios

# %%
municipios = pd.concat([municipios_cursos, municipios_instituicoes]).drop_duplicates().sort_values('NOME_MUNICIPIO').reset_index(drop=True)
municipios
# Out:
#       COD_MUNICIPIO       NOME_MUNICIPIO  UF        REGIAO
# 0           5200050      Abadia de Goiás  GO  CENTRO-OESTE
# 1           3100104  Abadia dos Dourados  MG       SUDESTE
# 2           5200100            Abadiânia  GO  CENTRO-OESTE
# 3           1500107           Abaetetuba  PA         NORTE
# 4           3100203               Abaeté  MG       SUDESTE
# ...             ...                  ...  ..           ...
# 3435        3500600   Águas de São Pedro  SP       SUDESTE
# 3436        3200136         Águia Branca  ES       SUDESTE
# 3437        3501301      Álvares Machado  SP       SUDESTE
# 3438        2900504        Érico Cardoso  BA      NORDESTE
# 3439        1505106               Óbidos  PA         NORTE
#
# [3440 rows x 4 columns]

# %% [markdown]
# ## ENADE

# %% [markdown]
# ### Seleção das colunas

# %%
enade_n = enade[["Código da IES", "Código do Curso", "Conceito Enade (Contínuo)"]].copy()

# %% [markdown]
# ### Ajuste dos nomes das colunas

# %%
enade_n = enade_n.rename(columns={"Código da IES": "CODIGO_IES", 
                       "Código do Curso": "CODIGO_CURSO",
                       "Conceito Enade (Contínuo)": "CONCEITO_ENADE"})

# %%
enade
# Out:
#        Ano  Código da Área    Área de Avaliação Grau Acadêmico  Código da IES  \
# 0     2022               2              DIREITO    Bacharelado              1
# 1     2022              13  CIÊNCIAS ECONÔMICAS    Bacharelado              1
# 2     2022              38       SERVIÇO SOCIAL    Bacharelado              1
# 3     2022              22   CIÊNCIAS CONTÁBEIS    Bacharelado              1
# 4     2022               1        ADMINISTRAÇÃO    Bacharelado              1
# ...    ...             ...                  ...            ...            ...
# 9891  2022               2              DIREITO    Bacharelado          25282
# 9892  2022              22   CIÊNCIAS CONTÁBEIS    Bacharelado          25352
# 9893  2022              18           PSICOLOGIA    Bacharelado          25352
# 9894  2022              13  CIÊNCIAS ECONÔMICAS    Bacharelado          25352
# 9895  2022               1        ADMINISTRAÇÃO    Bacharelado          25352
#
#                               Nome da IES* Sigla da IES*  \
# 0      UNIVERSIDADE FEDERAL DE MATO GROSSO          UFMT
# 1      UNIVERSIDADE FEDERAL DE MATO GROSSO          UFMT
# 2      UNIVERSIDADE FEDERAL DE MATO GROSSO          UFMT
# 3      UNIVERSIDADE FEDERAL DE MATO GROSSO          UFMT
# 4      UNIVERSIDADE FEDERAL DE MATO GROSSO          UFMT
# ...                                    ...           ...
# 9891         UNIVERSIDADE FEDERAL DE JATAÍ           UFJ
# 9892  Universidade Federal de Rondonópolis           UFR
# 9893  Universidade Federal de Rondonópolis           UFR
# 9894  Universidade Federal de Rondonópolis           UFR
# 9895  Universidade Federal de Rondonópolis           UFR
#
#      Organização Acadêmica Categoria Administrativa  Código do Curso  ...  \
# 0             Universidade          Pública Federal                1  ...
# 1             Universidade          Pública Federal                2  ...
# 2             Universidade          Pública Federal                7  ...
# 3             Universidade          Pública Federal                8  ...
# 4             Universidade          Pública Federal               13  ...
# ...                    ...                      ...              ...  ...
# 9891          Universidade          Pública Federal           120832  ...
# 9892          Universidade          Pública Federal               21  ...
# 9893          Universidade          Pública Federal            84854  ...
# 9894          Universidade          Pública Federal           123052  ...
# 9895          Universidade          Pública Federal          1127343  ...
#
#      Sigla da UF**   Nº de Concluintes Inscritos  \
# 0                MT                           91
# 1                MT                           36
# 2                MT                           57
# 3                MT                           84
# 4                MT                          124
# ...             ...                          ...
# 9891             GO                           56
# 9892             MT                           65
# 9893             MT                           22
# 9894             MT                           41
# 9895             MT                           54
#
#      Nº  de Concluintes Participantes Nota Bruta - FG  Nota Padronizada - FG  \
# 0                                  46          76.330                  4.686
# 1                                  29          60.872                  2.282
# 2                                  46          59.419                  3.163
# 3                                  73          59.404                  3.800
# 4                                  52          62.486                  3.899
# ...                               ...             ...                    ...
# 9891                               47          73.082                  4.313
# 9892                               36          50.369                  2.724
# 9893                               21          66.447                  3.144
# 9894                               33          54.600                  1.443
# 9895                               32          48.709                  2.299
#
#       Nota Bruta - CE  Nota Padronizada - CE  Conceito Enade (Contínuo)  \
# 0              59.004                  4.823                      4.788
# 1              31.110                  1.603                      1.772
# 2              55.754                  3.508                      3.421
# 3              27.146                  3.227                      3.370
# 4              49.657                  3.669                      3.726
# ...               ...                    ...                        ...
# 9891           54.453                  4.222                      4.244
# 9892           19.108                  1.401                      1.731
# 9893           67.380                  3.755                      3.601
# 9894           31.330                  1.640                      1.590
# 9895           44.687                  3.105                      2.903
#
#       Conceito Enade (Faixa)  Observação
# 0                          5         NaN
# 1                          2         NaN
# 2                          4         NaN
# 3                          4         NaN
# 4                          4         NaN
# ...                      ...         ...
# 9891                       5         NaN
# 9892                       2         NaN
# 9893                       4         NaN
# 9894                       2         NaN
# 9895                       3         NaN
#
# [9896 rows x 23 columns]

# %%
enade_n
# Out:
#       CODIGO_IES  CODIGO_CURSO  CONCEITO_ENADE
# 0              1             1           4.788
# 1              1             2           1.772
# 2              1             7           3.421
# 3              1             8           3.370
# 4              1            13           3.726
# ...          ...           ...             ...
# 9891       25282        120832           4.244
# 9892       25352            21           1.731
# 9893       25352         84854           3.601
# 9894       25352        123052           1.590
# 9895       25352       1127343           2.903
#
# [9896 rows x 3 columns]

# %% [markdown]
# ## Cursos

# %% [markdown]
# ### Seleção das colunas

# %%
cursos_n = cursos[["CODIGO_IES", "CODIGO_CURSO", "NOME_CURSO",
                   "GRAU", "MODALIDADE", "SITUACAO_CURSO",
                   "CARGA_HORARIA", "QT_VAGAS_AUTORIZADAS", 
                   "AREA_OCDE_CINE"]].copy()

# %% [markdown]
# ### Left join com dataset com dados sobre ENADE 2022

# %%
cursos_n = pd.merge(cursos_n, enade_n, how='left', on=['CODIGO_IES', 'CODIGO_CURSO'])

# %% [markdown]
# ### Ajuste dos nomes das colunas

# %%
cursos_n = cursos_n.rename(columns={'CODIGO_IES': 'COD_INSTITUICAO', 
                                    'CODIGO_CURSO': 'COD_CURSO',
                                    'QT_VAGAS_AUTORIZADAS': 'VAGAS_AUTORIZADAS',
                                    'SITUACAO_CURSO': 'SITUACAO',
                                    'AREA_OCDE_CINE': 'AREA_CURSO'})

# %%
cursos_n
# Out:
#         COD_INSTITUICAO  COD_CURSO             NOME_CURSO          GRAU  \
# 0                  4751    1556773  ENGENHARIA AGRONÔMICA   Bacharelado
# 1                  1491    1186955                 LETRAS  Licenciatura
# 2                  1472      99950              GEOGRAFIA  Licenciatura
# 3                   221    1467998        EDUCAÇÃO FÍSICA   Bacharelado
# 4                  1472    1516788        SERVIÇOS PENAIS   Tecnológico
# ...                 ...        ...                    ...           ...
# 902671              163    1518220       CIÊNCIA DE DADOS   Tecnológico
# 902672             1491    1468267                 MÚSICA  Licenciatura
# 902673             1491    1185929     CIÊNCIAS CONTÁBEIS   Bacharelado
# 902674              298      97329              MARKETING   Tecnológico
# 902675             3840    1375316  CIÊNCIA DA COMPUTAÇÃO   Bacharelado
#
#                   MODALIDADE      SITUACAO  CARGA_HORARIA  VAGAS_AUTORIZADAS  \
# 0       Educação a Distância  Em atividade           4400               1000
# 1       Educação a Distância  Em atividade           3992               3000
# 2       Educação a Distância  Em atividade           3500               7620
# 3       Educação a Distância  Em atividade           3200               1200
# 4       Educação a Distância  Em atividade           1980               1500
# ...                      ...           ...            ...                ...
# 902671  Educação a Distância  Em atividade           2086               2589
# 902672  Educação a Distância  Em atividade           3992               1700
# 902673  Educação a Distância  Em atividade           3260               4500
# 902674  Educação a Distância  Em atividade           1700               6000
# 902675  Educação a Distância  Em atividade           3215                300
#
#                                                AREA_CURSO  CONCEITO_ENADE
# 0                                               Agronomia             NaN
# 1       Formação de professor de língua/literatura ver...             NaN
# 2                      Formação de professor de geografia             NaN
# 3                                         Educação física             NaN
# 4                                         Serviços penais             NaN
# ...                                                   ...             ...
# 902671                                   Ciência de dados             NaN
# 902672                    Formação de professor de música             NaN
# 902673                                 Ciências contábeis           2.128
# 902674                                          Marketing           2.107
# 902675                              Ciência da computação             NaN
#
# [902676 rows x 10 columns]

# %% [markdown]
# ### Remoção de linhas duplicadas

# %%
cursos_n = cursos_n.drop_duplicates().reset_index(drop=True)
cursos_n
# Out:
#        COD_INSTITUICAO  COD_CURSO                   NOME_CURSO          GRAU  \
# 0                 4751    1556773        ENGENHARIA AGRONÔMICA   Bacharelado
# 1                 1491    1186955                       LETRAS  Licenciatura
# 2                 1472      99950                    GEOGRAFIA  Licenciatura
# 3                  221    1467998              EDUCAÇÃO FÍSICA   Bacharelado
# 4                 1472    1516788              SERVIÇOS PENAIS   Tecnológico
# ...                ...        ...                          ...           ...
# 86252             1077      54772                   PSICOLOGIA  Licenciatura
# 86253              569      12020           COMUNICAÇÃO SOCIAL   Bacharelado
# 86254             1042    1544956                ADMINISTRAÇÃO   Bacharelado
# 86255              376    1166015  LETRAS - PORTUGUÊS E INGLÊS  Licenciatura
# 86256             1879      51052  LETRAS - PORTUGUÊS E INGLÊS  Licenciatura
#
#                  MODALIDADE      SITUACAO  CARGA_HORARIA  VAGAS_AUTORIZADAS  \
# 0      Educação a Distância  Em atividade           4400               1000
# 1      Educação a Distância  Em atividade           3992               3000
# 2      Educação a Distância  Em atividade           3500               7620
# 3      Educação a Distância  Em atividade           3200               1200
# 4      Educação a Distância  Em atividade           1980               1500
# ...                     ...           ...            ...                ...
# 86252   Educação Presencial       Extinto           4196                210
# 86253   Educação Presencial       Extinto           2700                  0
# 86254   Educação Presencial  Em atividade           3000                 50
# 86255   Educação Presencial       Extinto           3620                270
# 86256   Educação Presencial       Extinto           3128                100
#
#                                               AREA_CURSO  CONCEITO_ENADE
# 0                                              Agronomia             NaN
# 1      Formação de professor de língua/literatura ver...             NaN
# 2                     Formação de professor de geografia             NaN
# 3                                        Educação física             NaN
# 4                                        Serviços penais             NaN
# ...                                                  ...             ...
# 86252                Formação de professor de psicologia             NaN
# 86253            Comunicação social (redação e conteúdo)             NaN
# 86254                                      Administração             NaN
# 86255  Formação de professor de língua/literatura ver...             NaN
# 86256  Formação de professor de língua/literatura ver...             NaN
#
# [86257 rows x 10 columns]

# %% [markdown]
# ## MUNICIPIO_has_CURSO

# %% [markdown]
# ### Seleção das colunas

# %%
municipio_has_curso = cursos[["CODIGO_CURSO", "CODIGO_MUNICIPIO"]].drop_duplicates().copy()

# %%
municipio_has_curso[municipio_has_curso.CODIGO_CURSO == 1]
# Out:
#         CODIGO_CURSO  CODIGO_MUNICIPIO
# 720487             1           5103403

# %%
municipios[municipios.COD_MUNICIPIO == 5103403]
# Out:
#      COD_MUNICIPIO NOME_MUNICIPIO  UF        REGIAO
# 957        5103403         Cuiabá  MT  CENTRO-OESTE

# %% [markdown]
# ### Ajuste dos nomes das colunas

# %%
municipio_has_curso = municipio_has_curso.rename(columns={'CODIGO_CURSO': 'CURSO_COD_CURSO', 
                                                          'CODIGO_MUNICIPIO': 'MUNICIPIO_COD_MUNICIPIO'})

# %%
municipio_has_curso
# Out:
#         CURSO_COD_CURSO  MUNICIPIO_COD_MUNICIPIO
# 0               1556773                  3541406
# 1               1186955                  2516201
# 2                 99950                  2800308
# 3               1467998                  4113205
# 4               1516788                  2601706
# ...                 ...                      ...
# 902671          1518220                  4300604
# 902672          1468267                  2704302
# 902673          1185929                  3554003
# 902674            97329                  2601102
# 902675          1375316                  3162104
#
# [902646 rows x 2 columns]

# %% [markdown]
# # Carregamento dos dados no banco

# %%
import mysql.connector

mydb = mysql.connector.connect(
  host="localhost",
  user="root",
  password="*****"
)

print(mydb)
# Out:
# <mysql.connector.connection_cext.CMySQLConnection object at 0x7fb207893790>

# %%
from sqlalchemy import create_engine

engine = create_engine("mysql+mysqlconnector://root:*****@localhost/mydb")

# %%
municipios.to_sql(name='MUNICIPIO', con=engine, schema='cursos_graduacao', if_exists='append', index=False)
# Out:
# 3440

# %%
instituicoes_n.to_sql(name='INSTITUICAO', con=engine, schema='cursos_graduacao', if_exists='append', index=False)
# Out:
# 3870

# %%
cursos_n.to_sql(name='CURSO', con=engine, schema='cursos_graduacao', if_exists='append', index=False, chunksize=25000, method=None)
# Out:
# 86257

# %%
municipio_has_curso.to_sql(name='MUNICIPIO_has_CURSO', con=engine, schema='cursos_graduacao', if_exists='append', index=False, chunksize=25000, method=None)
# Out:
# 902646
